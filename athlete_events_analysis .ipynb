# %%
import pandas as pd
import seaborn as sns

# %%
sportsstats = pd.read_csv('/Project/athlete_events.csv')

# %%
sportsstats
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df = pd.DataFrame(sportsstats)

# %%
# sportsstats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# sportsstats.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# print("First Event: ",sportsstats.Year.min())
# print("Last Event: ",sportsstats.Year.max())
# Out:
# First Event:  1896
# Last Event:  2016

# %%
# sns.lineplot(x="Age",y="Year",data=sportsstats)

# %%
# sportsstats.Year.hist()

# %%
# sportsstats.head(17)

# %%
# pd.set_option('display.max_colwidth',0)
# sportsstats.head(17)

# %%
# from pandasql import sqldf as sql

# %%
# sqlalchemy.create_engine('oracle://scott:tiger@127.0.0.1:1521/sidname')
# %load_ext sql
# %sql sqlite://

# %%
# %%sql
# CREATE TABLE athlete_data(ID int(10), Name char(30), Sex char(3), Age int(3), Height int(4), Weight int(4), Team char(30), NOC char(10), Games char(30),
#                           Year int(4), Season char(15), City char(30),Sport char(20),Event char(30),Medal char(10))
# Out:
#  * sqlite://
# Done.
# []

# %%
# %%sql
# select * from athlete_data
# Out:
#  * sqlite://
# Done.
# []

# %%
# %%sql
# select * from sportsstats
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: sportsstats
# [SQL: select * from sportsstats]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
import ast

# %%
# sportsstats['event_decode']=sportsstats['Medal'].apply(lambda x:ast.literal_eval(x).decode("utf-8"))

# %%
sportsstats.head(17)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1   A Dijiang                 M   24.0  180.0   80.0    China
# 1   2   A Lamusi                  M   23.0  170.0   60.0    China
# 2   3   Gunnar Nielsen Aaby       M   24.0 NaN     NaN      Denmark
# 3   4   Edgar Lindenau Aabye      M   34.0 NaN     NaN      Denmark/Sweden
# 4   5   Christine Jacoba Aaftink  F   21.0  185.0   82.0    Netherlands
# 5   5   Christine Jacoba Aaftink  F   21.0  185.0   82.0    Netherlands
# 6   5   Christine Jacoba Aaftink  F   25.0  185.0   82.0    Netherlands
# 7   5   Christine Jacoba Aaftink  F   25.0  185.0   82.0    Netherlands
# 8   5   Christine Jacoba Aaftink  F   27.0  185.0   82.0    Netherlands
# 9   5   Christine Jacoba Aaftink  F   27.0  185.0   82.0    Netherlands
# 10  6   Per Knut Aaland           M   31.0  188.0   75.0    United States
# 11  6   Per Knut Aaland           M   31.0  188.0   75.0    United States
# ...

# %%
# for i in sportsstats:

#         print(sportsstats.loc[i, "Name"], sportsstats.loc[i, "Age"])
# print(athlete_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 4>()
#       1 # for i in sportsstats:
#       2
#       3 #         print(sportsstats.loc[i, "Name"], sportsstats.loc[i, "Age"])
# ----> 4 print(athlete_data)
#
# NameError: name 'athlete_data' is not defined

# %%
# sql("CREATE TABLE sports USING csv OPTIONS (path '/Project/noc_regions.csv';)")

# %%
import erdantic
from erdantic.examples.pydantic import Party
diagram = erd.create(Party)
diagram
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 import erdantic
#       2 from erdantic.examples.pydantic import Party
#       3 diagram = erd.create(Party)
#
# ModuleNotFoundError: No module named 'erdantic'

# %%
print(df)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# import mysql.connector

# %%
# # try:
#     connection = mysql.connector.connect(host='localhost',
#                                          database='Harshit',
#                                          user='harshit',
#                                          password='jarvis@4317')
#     if connection.is_connected():
#         db_Info = connection.get_server_info()
#         print("Connected to MySQL Server version ", db_Info)
#         cursor = connection.cursor()
#         cursor.execute("select database();")
#         record = cursor.fetchone()
#         print("You're connected to database: ", record)

# except Error as e:
#     print("Error while connecting to MySQL", e)
# finally:
#     if connection.is_connected():
#         cursor.close()
#         connection.close()
#         print("MySQL connection is closed")
# Out:
# Error while connecting to MySQL 2003 (HY000): Can't connect to MySQL server on 'localhost:3306' (10061)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#      17     print("Error while connecting to MySQL", e)
#      18 finally:
# ---> 19     if connection.is_connected():
#      20         cursor.close()
#      21         connection.close()
#
# NameError: name 'connection' is not defined

# %%
import sqlite3
 
# connecting to the database
connection = sqlite3.connect("gfg.db")
 
# cursor
crsr = connection.cursor()
for row in df.itertuples():
    crsr.execute('''
                INSERT INTO athlete_data (ID,Name,Sex,Age,Height,Weight,Team,NOC,Games,Year,Season,City,Sport,Event,Medal)
                VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
                ''',
                 row.ID,
                 row.Name,
                 row.Sex,row.Age,
                 row.Height,
                 row.Weight,
                 row.Team,
                 row.NOC,
                 row.Games,
                 row.Year,
                 row.Season,
                 row.City,
                 row.Sport,
                 row.Event,
                 row.Medal
                )
# print statement will execute if there
# are no errors
print("Connected to the database")
 
# close the connection
connection.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 8>()
#       7 crsr = connection.cursor()
#       8 for row in df.itertuples():
# ----> 9     crsr.execute('''
#      10                 INSERT INTO athlete_data (ID,Name,Sex,Age,Height,Weight,Team,NOC,Games,Year,Season,City,Sport,Event,Medal)
#      11                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#      12                 ''',
#      13                  row.ID,
#      14                  row.Name,
#      15                  row.Sex,row.Age,
#      16                  row.Height,
#      17                  row.Weight,
#      18                  row.Team,
#      19                  row.NOC,
#      20                  row.Games,
#      21                  row.Year,
#      22                  row.Season,
#      23                  row.City,
#      24                  row.Sport,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
#       1 for row in df.itertuples():
# ----> 2     crsr.execute('''
#       3                 INSERT INTO athlete_data (ID,Name,Sex,Age,Height,Weight,Team,NOC,Games,Year,Season,City,Sport,Event,Medal)
#       4                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#       5                 ''',
#       6                  row.ID,
#       7                  row.Name,
#       8                  row.Sex,row.Age,
#       9                  row.Height,
#      10                  row.Weight,
#      11                  row.Team,
#      12                  row.NOC,
#      13                  row.Games,
#      14                  row.Year,
#      15                  row.Season,
#      16                  row.City,
#      17                  row.Sport,
#      18                  row.Event,
# ...

# %%
# Out:
#  * sqlite://
# (sqlite3.OperationalError) unrecognized token: "@"
# [SQL: SELECT @@SERVERNAME]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
conn = pyodbc.connect('Driver={};'
                      'Server=RON\SQLEXPRESS;'
                      'Database=test_database;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 conn = pyodbc.connect('Driver={SQL Server};'
#       2                       'Server=RON\SQLEXPRESS;'
#       3                       'Database=test_database;'
#       4                       'Trusted_Connection=yes;')
#       5 cursor = conn.cursor()
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (53)')

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('test_database')
c = conn.cursor()

c.execute('CREATE TABLE IF NOT EXISTS products (product_name text, price number)')
conn.commit()

data = {'product_name': ['Computer','Tablet','Monitor','Printer'],
        'price': [900,300,450,150]
        }

df = pd.DataFrame(data, columns= ['product_name','price'])
df.to_sql('products', conn, if_exists='replace', index = False)
 
c.execute('''  
SELECT * FROM products
          ''')

for row in c.fetchall():
    print (row)
